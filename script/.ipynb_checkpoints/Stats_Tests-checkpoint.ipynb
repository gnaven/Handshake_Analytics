# %% [markdown]
# ### In this notebook we show summary stats, correlations, statistical tests and exploratory analysis on the Handshake Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
Master_fname = '../data/all_data_numeric.csv'
df = pd.read_csv(Master_fname)

# %%
#columns in this dataset names
df.columns
# Out:
# Index(['Students Username', 'US Citizen', 'School Year Name',
#        'Educations Cumulative Gpa', 'Documents Count', 'Drop_in_advisor',
#        'Appointment Type Length (Minutes)', 'days_before_due', 'pre_reg',
#        'check_in', 'Engaged_Fair', 'Engaged_Appointment', 'Engaged_Jobs'],
#       dtype='object')

# %% [markdown]
# ##### finding correlations

# %%
usecols = ['US Citizen', 'School Year Name','Educations Cumulative Gpa', 
           'Documents Count', 'Drop_in_advisor','Appointment Type Length (Minutes)',
           'days_before_due', 'pre_reg','check_in', 'Engaged_Fair', 
           'Engaged_Appointment', 'Engaged_Jobs']
df_corr = df[usecols].corr().abs()

# %%
sns.heatmap(df_corr, 
        xticklabels=df_corr.columns,
        yticklabels=df_corr.index)

# %%
student_cols = ['US Citizen','School Year Name','Educations Cumulative Gpa','Documents Count','Engaged_Fair',
                'Engaged_Appointment','Engaged_Jobs']
df_corr_student = df[student_cols].corr().abs()
sns.heatmap(df_corr_student, 
        xticklabels=df_corr_student.columns,
        yticklabels=df_corr_student.index)

# %%
pair_cols = ['US Citizen','Educations Cumulative Gpa','School Year Name','Documents Count','Engaged_Fair',
                'Engaged_Appointment','Engaged_Jobs']
sns.pairplot(df[pair_cols].dropna());

# %%
x = df['Educations Cumulative Gpa'].max()
df[df['Educations Cumulative Gpa'] == x]
# Out:
#     Students Username  US Citizen  School Year Name  \
# 890          dbignall           1               5.0
#
#      Educations Cumulative Gpa  Documents Count  Drop_in_advisor  \
# 890                       92.0                5              0.0
#
#      Appointment Type Length (Minutes)  days_before_due  pre_reg  check_in  \
# 890                               30.0             12.0      1.0       1.0
#
#      Engaged_Fair  Engaged_Appointment  Engaged_Jobs
# 890             1                    1             1

# %%
sns.distplot(df['Educations Cumulative Gpa'].dropna())

# %% [markdown]
# ##### Stats tests

# %%
from scipy.stats import mannwhitneyu as mw
from scipy.stats import ttest_ind as tt

# %%
def stats(df, grp):        
    print('group name: '+ grp)
    for feature in df.columns:
        engaged = df[df[grp]==1][feature]
        not_engaged = df[df[grp]==0][feature]

        t_d, t_pval = mw(engaged, not_engaged)
        mw_d, mw_pval = mw(engaged,not_engaged)

        print('feature name ', feature)
        print('t-test p value: ', t_pval)
        print('MW p value: ',mw_pval)
        print('engaged mean: ', engaged.mean())
        print('not engaged mean: ',not_engaged.mean())
        print()

# %%
y_list = ['Engaged_Jobs','Engaged_Fair','Engaged_Appointment']
feat_names = ['US Citizen','School Year Name','Educations Cumulative Gpa','Documents Count','Engaged_Fair',
            'Engaged_Appointment','Engaged_Jobs']
df_stats = df[feat_names].dropna()
for y in y_list:
    stats(df_stats,y)
# Out:
# group name: Engaged_Jobs
# feature name  US Citizen
# t-test p value:  1.08569232096e-11
# MW p value:  1.08569232096e-11
# engaged mean:  0.6361236802413273
# not engaged mean:  0.7105831533477321
#
# feature name  School Year Name
# t-test p value:  1.42941481863e-168
# MW p value:  1.42941481863e-168
# engaged mean:  3.633107088989442
# not engaged mean:  2.684861574710387
#
# feature name  Educations Cumulative Gpa
# t-test p value:  4.98847793559e-09
# MW p value:  4.98847793559e-09
# engaged mean:  3.4879788838612362
# not engaged mean:  3.328435107009627
#
# feature name  Documents Count
# t-test p value:  0.0
# MW p value:  0.0
# engaged mean:  5.02526395173454
# not engaged mean:  0.13292754761437267
#
# feature name  Engaged_Fair
# t-test p value:  1.63394816907e-307
# MW p value:  1.63394816907e-307
# engaged mean:  0.5169683257918553
# not engaged mean:  0.12409189083055173
#
# feature name  Engaged_Appointment
# t-test p value:  5.5682272245e-199
# MW p value:  5.5682272245e-199
# engaged mean:  0.7205882352941176
# not engaged mean:  0.36069114470842334
#
# feature name  Engaged_Jobs
# t-test p value:  0.0
# MW p value:  0.0
# engaged mean:  1.0
# not engaged mean:  0.0
#
# group name: Engaged_Fair
# feature name  US Citizen
# t-test p value:  9.75761346926e-17
# MW p value:  9.75761346926e-17
# engaged mean:  0.6115826260609086
# not engaged mean:  0.710727969348659
#
# feature name  School Year Name
# t-test p value:  5.85789651082e-98
# MW p value:  5.85789651082e-98
# engaged mean:  3.5886170743884174
# not engaged mean:  2.8075583420411006
#
# feature name  Educations Cumulative Gpa
# t-test p value:  3.97772458014e-05
# MW p value:  3.97772458014e-05
# engaged mean:  3.4819720419370914
# not engaged mean:  3.348563218390816
#
# feature name  Documents Count
# t-test p value:  0.0
# MW p value:  0.0
# engaged mean:  4.480279580629056
# not engaged mean:  0.8760013932427726
#
# feature name  Engaged_Fair
# t-test p value:  0.0
# MW p value:  0.0
# engaged mean:  1.0
# not engaged mean:  0.0
#
# feature name  Engaged_Appointment
# t-test p value:  5.31116091655e-175
# MW p value:  5.31116091655e-175
# engaged mean:  0.7548676984523215
# not engaged mean:  0.3894113549285963
#
# feature name  Engaged_Jobs
# t-test p value:  1.63394816907e-307
# MW p value:  1.63394816907e-307
# engaged mean:  0.6844732900649027
# not engaged mean:  0.22309299895506793
#
# group name: Engaged_Appointment
# feature name  US Citizen
# t-test p value:  0.193046568131
# MW p value:  0.193046568131
# engaged mean:  0.6803628601921025
# not engaged mean:  0.6895171378533901
#
# feature name  School Year Name
# t-test p value:  1.85476098562e-46
# MW p value:  1.85476098562e-46
# engaged mean:  3.25
# not engaged mean:  2.784088066049537
#
# feature name  Educations Cumulative Gpa
# t-test p value:  2.02155675898e-08
# MW p value:  2.02155675898e-08
# engaged mean:  3.449959978655284
# not engaged mean:  3.320337753314991
#
# feature name  Documents Count
# t-test p value:  1.95686292532e-231
# MW p value:  1.95686292532e-231
# engaged mean:  2.9132870864461045
# not engaged mean:  0.7718288716537403
#
# feature name  Engaged_Fair
# t-test p value:  5.31116091655e-175
# MW p value:  5.31116091655e-175
# engaged mean:  0.4034151547491996
# not engaged mean:  0.12284213159869903
#
# feature name  Engaged_Appointment
# t-test p value:  0.0
# MW p value:  0.0
# engaged mean:  1.0
# not engaged mean:  0.0
#
# feature name  Engaged_Jobs
# t-test p value:  5.5682272245e-199
# MW p value:  5.5682272245e-199
# engaged mean:  0.509871931696905
# not engaged mean:  0.185389041781336

# %% [markdown]
# ##### co-efficient weights and p-values from logistic regression model

# %%
import statsmodels.formula.api as sm

# %%
def logit(df_m,y_m):
    X = df_m.copy()
    #X['intercept'] = 1
    model = sm.Logit(y_m, X)
    result = model.fit()
    print(result.summary())

# %%
y_list = ['Engaged_Jobs','Engaged_Fair','Engaged_Appointment']
feat_names = ['US Citizen','School Year Name','Educations Cumulative Gpa','Documents Count','Engaged_Fair',
            'Engaged_Appointment','Engaged_Jobs']
df_logit = df[feat_names].dropna()
for y in y_list:
    feat_names.remove(y)
    logit(df_logit,df_logit[y])
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: inf
#          Iterations: 35
# C:\Program Files\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:1674: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-X))
# C:\Program Files\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:1724: RuntimeWarning: divide by zero encountered in log
#   return np.sum(np.log(self.cdf(q*np.dot(X,params))))
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-48-8631c29901fe> in <module>()
#       5 for y in y_list:
#       6     feat_names.remove(y)
# ----> 7     logit(df_logit,df_logit[y])
#
# <ipython-input-47-ae9d9c66179a> in logit(df_m, y_m)
#       3     #X['intercept'] = 1
#       4     model = sm.Logit(y_m, X)
# ----> 5     result = model.fit()
#       6     print(result.summary())
#
# C:\Program Files\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#    1832         bnryfit = super(Logit, self).fit(start_params=start_params,
#    1833                 method=method, maxiter=maxiter, full_output=full_output,
# -> 1834                 disp=disp, callback=callback, **kwargs)
#    1835
#    1836         discretefit = LogitResults(self, bnryfit)
#
# C:\Program Files\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#     218         mlefit = super(DiscreteModel, self).fit(start_params=start_params,
#     219                 method=method, maxiter=maxiter, full_output=full_output,
# --> 220                 disp=disp, callback=callback, **kwargs)
#     221
#     222         return mlefit # up to subclasses to wrap results
#
# C:\Program Files\Anaconda3\lib\site-packages\statsmodels\base\model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     471             Hinv = cov_params_func(self, xopt, retvals)
#     472         elif method == 'newton' and full_output:
# --> 473             Hinv = np.linalg.inv(-retvals['Hessian']) / nobs
#     474         elif not skip_hessian:
#     475             H = -1 * self.hessian(xopt)
#
# C:\Program Files\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in inv(a)
#     511     signature = 'D->D' if isComplexType(t) else 'd->d'
#     512     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 513     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     514     return wrap(ainv.astype(result_t, copy=False))
#     515
#
# C:\Program Files\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_singular(err, flag)
#      88
#      89 def _raise_linalgerror_singular(err, flag):
# ---> 90     raise LinAlgError("Singular matrix")
#      91
#      92 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
